# %% [markdown]
# <a href="https://colab.research.google.com/github/VQHoangViet/19512321_PhanLeHoangViet_AD_HW1/blob/main/Report_BI_tool_check_POD_version3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pat = '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'
# !git pull https://{pat}@github.com/VQHoangViet/fakefail_report_tool.git
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
from fakefail_report_tool import Report_BI_tool_check_POD_version3_1 as ff
# Out:
# hello Ninja3_1!!!
# Mounted at /content/drive

# %%
df = ff.read_pipeline(url_agg='/content/query_result_2022-11-03T07_37_54.51607Z.csv')
# Out:
# Final: ----------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-9cc3a10ec1be> in <module>
# ----> 1 df = ff.read_pipeline(url_agg='/content/query_result_2022-11-03T07_37_54.51607Z.csv')
#
# /content/fakefail_report_tool/Report_BI_tool_check_POD_version3_1.py in read_pipeline(url_agg)
#     345   print('Final: ' + '-'*100)
#     346   final = compute_phase(driver)
# --> 347   export_final_driver_file(final)
#     348   return final
#
# /content/fakefail_report_tool/Report_BI_tool_check_POD_version3_1.py in export_final_driver_file(final)
#     292   final = final.sort_values('first_attempt_date')
#     293   # raw_data.to_csv('/content/sample_data/final_driver_data.csv')
# ...

# %%
df
# Out:
#                       tracking_id     callee    attempt_datetime  \
# 116904             BPT2309TKGD052  343026957 2022-09-26 06:24:22
# 116906              AWM1709226100  983564033 2022-09-26 06:25:42
# 116907         PCAKES4640025O1585  976043245 2022-09-26 06:27:06
# 41                KNJVN0101044027  344661894 2022-09-26 06:32:05
# 116908          PCAKES4604674O576  343508345 2022-09-26 06:38:29
# ...                           ...        ...                 ...
# 2285052      PCAKES20002164O37073  335130754 2022-11-01 23:27:50
# 2560762        NVVNLEPHC000365460  835447497 2022-11-01 23:28:50
# 2282278      PCAKES1945791O668513  359902390 2022-11-01 23:29:55
# 2560764  HRV1000277297-1110816266  909239917 2022-11-01 23:31:29
# 1852093             BIG5000082064  975207709 2022-11-01 23:37:54
#
#                                             reason  \
# 116904                Khách hàng muốn hủy đơn hàng
# 116906                Khách hàng muốn hủy đơn hàng
# ...
